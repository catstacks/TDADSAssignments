# %% [markdown]
# # FAKE NEWS

# %% [markdown]
# ## Assignment brief
#
# This dataset contains information on a number of social media posts and classifies them as real or fake news. Example insight: Can you build a machine learning model to detect which posts are likely to be fake news?
#
# File name: news_articles.csv
#
# Find out more about this dataset [here](https://www.kaggle.com/ruchi798/source-based-news-classification)
#
#
# *Extension:* To extend the project, try using two different supervised learning algorithms and use methods to
# measure their accuracy. Which model would you choose? Why?

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
news = pd.read_csv('news_articles.csv')
news.head()
# Out:
#                  author                      published  \
# 0     Barracuda Brigade  2016-10-26T21:41:00.000+03:00
# 1  reasoning with facts  2016-10-29T08:47:11.259+03:00
# 2     Barracuda Brigade  2016-10-31T01:41:49.479+02:00
# 3                Fed Up  2016-11-01T05:22:00.000+02:00
# 4                Fed Up  2016-11-01T21:56:00.000+02:00
#
#                                                title  \
# 0  muslims busted they stole millions in govt ben...
# 1  re why did attorney general loretta lynch plea...
# 2  breaking weiner cooperating with fbi on hillar...
# 3  pin drop speech by father of daughter kidnappe...
# 4  fantastic trumps  point plan to reform healthc...
#
#                                                 text language  \
# 0  print they should pay all the back all the mon...  english
# 1  why did attorney general loretta lynch plead t...  english
# 2  red state  \nfox news sunday reported this mor...  english
# ...

# %%
news.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2096 entries, 0 to 2095
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   author                   2096 non-null   object
#  1   published                2096 non-null   object
#  2   title                    2096 non-null   object
#  3   text                     2050 non-null   object
#  4   language                 2095 non-null   object
#  5   site_url                 2095 non-null   object
#  6   main_img_url             2095 non-null   object
#  7   type                     2095 non-null   object
#  8   label                    2095 non-null   object
#  9   title_without_stopwords  2094 non-null   object
#  10  text_without_stopwords   2046 non-null   object
#  11  hasImage                 2095 non-null   float64
# dtypes: float64(1), object(11)
# memory usage: 196.6+ KB

# %%
news.isnull().sum()
# Out:
# author                      0
# published                   0
# title                       0
# text                       46
# language                    1
# site_url                    1
# main_img_url                1
# type                        1
# label                       1
# title_without_stopwords     2
# text_without_stopwords     50
# hasImage                    1
# dtype: int64

# %%
news.isnull()
# Out:
#       author  published  title   text  language  site_url  main_img_url  \
# 0      False      False  False  False     False     False         False
# 1      False      False  False  False     False     False         False
# 2      False      False  False  False     False     False         False
# 3      False      False  False  False     False     False         False
# 4      False      False  False  False     False     False         False
# ...      ...        ...    ...    ...       ...       ...           ...
# 2091   False      False  False   True     False     False         False
# 2092   False      False  False   True     False     False         False
# 2093   False      False  False   True     False     False         False
# 2094   False      False  False   True     False     False         False
# 2095   False      False  False   True      True      True          True
#
#        type  label  title_without_stopwords  text_without_stopwords  hasImage
# ...

# %%
news.groupby(['author']).count()
# Out:
#                                                     published  title  text  \
# author
# # 1 NWO Hatr                                                3      3     3
# -NO AUTHOR-                                                58     58    24
# 4 Goals For The Neomasculinity Movement During ...          1      1     1
# ?????? ???? ???? ?????????                                  1      1     1
# A. Griffee                                                  2      2     2
# ...                                                       ...    ...   ...
# watchmannonthewall                                          1      1     1
# willz                                                       1      1     1
# wmw_admin                                                   1      1     1
# wtromp@operamail.com (WT)                                   2      2     2
# xuenchen                                                    3      3     3
#
# ...

# %%
news.groupby(['type']).count()
# Out:
#             author  published  title  text  language  site_url  main_img_url  \
# type
# bias           436        436    436   393       436       436           436
# bs             601        601    601   599       601       601           601
# conspiracy     430        430    430   430       430       430           430
# fake            15         15     15    15        15        15            15
# hate           244        244    244   244       244       244           244
# junksci        102        102    102   102       102       102           102
# satire         146        146    146   146       146       146           146
# state          121        121    121   121       121       121           121
#
#             label  title_without_stopwords  text_without_stopwords  hasImage
# type
# bias          436                      436                     389       436
# bs            601                      600                     599       601
# ...

# %%
news.groupby(['language']).count()
# Out:
#           author  published  title  text  site_url  main_img_url  type  label  \
# language
# english     2017       2017   2017  1972      2017          2017  2017   2017
# french         2          2      2     2         2             2     2      2
# german        72         72     72    72        72            72    72     72
# ignore         3          3      3     3         3             3     3      3
# spanish        1          1      1     1         1             1     1      1
#
#           title_without_stopwords  text_without_stopwords  hasImage
# language
# english                      2016                    1968      2017
# french                          2                       2         2
# german                         72                      72        72
# ignore                          3                       3         3
# spanish                         1                       1         1

# %%
#https://scikit-learn.org/stable/modules/feature_extraction.html
